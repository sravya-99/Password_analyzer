# %% [markdown]
# <a href="https://colab.research.google.com/github/sravya-99/Password_analyzer/blob/main/Password_Strength_Analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
password = input("Enter Password: ")

print("Your Password:", password)
# Out:
# Enter Password: sravya-W
# Your Password: sravya-W

# %%
password = input("Enter Password: ")

if len(password) < 8:
    print("Weak Password")
else:
    print("Good Length")
# Out:
# Enter Password: sravya-W
# Good Length

# %%
import re

password = input("Enter Password: ")

if re.search(r"[A-Z]", password):
    print("Uppercase Found")
else:
    print("No Uppercase")

if re.search(r"[a-z]", password):
    print("Lowercase Found")

if re.search(r"\d", password):
    print("Number Found")

if re.search(r"[^A-Za-z0-9]", password):
    print("Special Character Found")
# Out:
# Enter Password: sravya-W
# Uppercase Found
# Lowercase Found
# Special Character Found

# %%
import re

password = input("Enter Password: ")

score = 0

if len(password) >= 8:
    score += 1

if re.search(r"[A-Z]", password):
    score += 1

if re.search(r"[a-z]", password):
    score += 1

if re.search(r"\d", password):
    score += 1

if re.search(r"[^A-Za-z0-9]", password):
    score += 1

print("Score:", score)
# Out:
# Enter Password: sravya-W
# Score: 4

# %%
if score <= 2:
    print("Strength: Weak")
elif score <= 4:
    print("Strength: Moderate")
else:
    print("Strength: Strong")
# Out:
# Strength: Moderate

# %%
suggestions = []

if len(password) < 8:
    suggestions.append("Increase length")

if not re.search(r"[A-Z]", password):
    suggestions.append("Add uppercase letters")

if not re.search(r"\d", password):
    suggestions.append("Add numbers")

if not re.search(r"[^A-Za-z0-9]", password):
    suggestions.append("Add special characters")

print("\nSuggestions:")

for item in suggestions:
    print("-", item)
# Out:
# Suggestions:
# - Add numbers

# %%
import random
import string

characters = (
    string.ascii_letters +
    string.digits +
    string.punctuation
)

strong_password = ''.join(
    random.choice(characters)
    for _ in range(16)
)

print("Suggested Password:")
print(strong_password)
# Out:
# Suggested Password:
# !,A<j{=AA,8Vn'fi

# %%
import math

charset = 94

entropy = len(password) * math.log2(charset)

print("Entropy:", round(entropy, 2))
# Out:
# Entropy: 52.44

# %%
def check_strength(password):
    pass

def suggest_password():
    pass

def calculate_entropy(password):
    pass

# %%
import ipywidgets as widgets
from IPython.display import display

password_box = widgets.Password(
    description='Password:'
)

display(password_box)
# Out:
# Password(description='Password:')
